# %% [markdown]
# <a href="https://colab.research.google.com/github/LC1332/Haruhi-2-Dev/blob/main/notebook/test_pull_role_form_hf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install transformers openai tiktoken langchain chromadb datasets
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.5/7.5 MB 46.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 68.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 68.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 418.3/418.3 kB 32.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.3/519.3 kB 35.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 99.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 67.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
# %cd /content
# !rm -rf /content/Haruhi-2-Dev
# !git clone https://github.com/LC1332/Haruhi-2-Dev
# %cd /content/Haruhi-2-Dev
# Out:
# /content
# Cloning into 'Haruhi-2-Dev'...
# remote: Enumerating objects: 723, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 723 (delta 14), reused 21 (delta 9), pack-reused 693
# Receiving objects: 100% (723/723), 105.67 MiB | 27.83 MiB/s, done.
# Resolving deltas: 100% (344/344), done.
# /content/Haruhi-2-Dev

# %%
import os

key = 'sk-VvF'
key_bytes = key.encode()
os.environ["OPENAI_API_KEY"] = key_bytes.decode('utf-8')

# %%
from ChatHaruhi import ChatHaruhi

chatbot = ChatHaruhi( role_from_hf = 'chengli-thu/yuebuqun', \
                      llm = 'openai')

response = chatbot.chat(role='令狐冲', text = '师傅，冲儿来了')
print(response)
# Out:
# ...
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# 正在下载Luotuo-Bert
# ...
# A new version of the following files was downloaded from https://huggingface.co/silk-road/luotuo-bert-medium:
# - models.py
# . Make sure to double-check they do not contain any added malicious code. To avoid downloading new versions of the code file, you can pin a revision.
# ...
# Luotuo-Bert下载完毕
# ...
# 岳不群:「冲儿，你来了啊。怎么样，最近练功有没有进步？」

# %%
response = chatbot.chat(role='令狐冲', text = '师傅，我是冬练三九，夏练三伏啊')
print(response)
# Out:
# 岳不群:「哈哈哈，不错不错。你这个孩子，练功真是刻苦啊。冬练三九，夏练三伏，正是磨砺自己的好时机。只有经过苦练，才能在江湖中立足嘛。不过，也要注意身体，不要过度劳累，要适度休息，保持身心的平衡。」
